# %% [markdown]
# <a href="https://colab.research.google.com/github/EdgarErh/E50A-E01/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mineria de datos

# %% [markdown]
# ## Primer parcial

# %% [markdown]
# ### Introducción

# %% [markdown]
# #### Conceptos

# %% [markdown]
# #### Ciencia de datos

# %% [markdown]
# ##### Help and documentacion in IPhyton

# %%
#LA función help nos muestra la ayuda
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
# otra forma de obtener ayuda es utilizando ?
len?

# %%
#ejemplo de ayuda en una lista
L = [1, 2, 3]
L.insert?

# %%
#ejemplode ayuda
L?

# %%
def square(a):
  """Return the square of a."""
  return a ** 2

# %%
help(square)
# Out:
# Help on function square in module __main__:
#
# square(a)
#     Return the square of a.

# %%
square?
# Out:
# Object `square` not found.

# %%
square??
# Out:
# Object `square` not found.

# %%
len??

# %%
L.append
# Out:
# <function list.append(object, /)>

# %%
L.clear
# Out:
# <function list.clear()>

# %%
L.copy
# Out:
# <function list.copy()>

# %%
L.count
# Out:
# <function list.count(value, /)>

# %%
L.__add__
# Out:
# <method-wrapper '__add__' of list object at 0x7d2c0b3afe40>

# %%
from itertools import combinations

# %%
import
# Out:
#   File "/tmp/ipython-input-2125240012.py", line 1
#     import
#           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### Mineria de datos

# %% [markdown]
# La Mineria de datos: es un proceso para analizar datos en volumenes, esto sirve para descubrir patrones, tendencias y correlaciones ocultas, asi de esta manera se transforma la información cruda en conocimiento util para predecir y tomar decisiones con estrategia en negocios o grandes empresas, ayudando al futuro de estas en cuanto a ventas o avances dentro de ellas.
